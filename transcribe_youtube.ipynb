# %% [markdown]
# <a href="https://colab.research.google.com/github/syeuk2002/tortoise-tts/blob/main/transcribe_youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Youtube Videos Transcription with OpenAI's Whisper**
#
# [![blog post shield](https://img.shields.io/static/v1?label=&message=Blog%20post&color=blue&style=for-the-badge&logo=openai&link=https://openai.com/blog/whisper)](https://openai.com/blog/whisper)
# [![notebook shield](https://img.shields.io/static/v1?label=&message=Notebook&color=blue&style=for-the-badge&logo=googlecolab&link=https://colab.research.google.com/github/ArthurFDLR/whisper-youtube/blob/main/whisper_youtube.ipynb)](https://colab.research.google.com/github/ArthurFDLR/whisper-youtube/blob/main/whisper_youtube.ipynb)
# [![repository shield](https://img.shields.io/static/v1?label=&message=Repository&color=blue&style=for-the-badge&logo=github&link=https://github.com/openai/whisper)](https://github.com/openai/whisper)
# [![paper shield](https://img.shields.io/static/v1?label=&message=Paper&color=blue&style=for-the-badge&link=https://cdn.openai.com/papers/whisper.pdf)](https://cdn.openai.com/papers/whisper.pdf)
# [![model card shield](https://img.shields.io/static/v1?label=&message=Model%20card&color=blue&style=for-the-badge&link=https://github.com/openai/whisper/blob/main/model-card.md)](https://github.com/openai/whisper/blob/main/model-card.md)
#
# Whisper is a general-purpose speech recognition model. It is trained on a large dataset of diverse audio and is also a multi-task model that can perform multilingual speech recognition as well as speech translation and language identification.
#
# This Notebook will guide you through the transcription of a Youtube video using Whisper. You'll be able to explore most inference parameters or use the Notebook as-is to store the transcript and video audio in your Google Drive.

# %%
#@markdown # **Check GPU type** 🕵️

#@markdown The type of GPU you get assigned in your Colab session defined the speed at which the video will be transcribed.
#@markdown The higher the number of floating point operations per second (FLOPS), the faster the transcription.
#@markdown But even the least powerful GPU available in Colab is able to run any Whisper model.
#@markdown Make sure you've selected `GPU` as hardware accelerator for the Notebook (Runtime &rarr; Change runtime type &rarr; Hardware accelerator).

#@markdown |  GPU   |  GPU RAM   | FP32 teraFLOPS |     Availability   |
#@markdown |:------:|:----------:|:--------------:|:------------------:|
#@markdown |  T4    |    16 GB   |       8.1      |         Free       |
#@markdown | P100   |    16 GB   |      10.6      |      Colab Pro     |
#@markdown | V100   |    16 GB   |      15.7      |  Colab Pro (Rare)  |

#@markdown ---
#@markdown **Factory reset your Notebook's runtime if you want to get assigned a new GPU.**

# !nvidia-smi -L

# !nvidia-smi
# Out:
# GPU 0: Tesla T4 (UUID: GPU-db1f939a-9493-4777-0af8-a665e2766cfa)
# Wed May 24 14:39:28 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8    12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#@markdown # **Install libraries** 🏗️
#@markdown This cell will take a little while to download several libraries, including Whisper.

#@markdown ---

! pip install git+https://github.com/openai/whisper.git
! pip install yt-dlp

import sys
import warnings
import whisper
from pathlib import Path
import yt_dlp
import subprocess
import torch
import shutil
import numpy as np
from IPython.display import display, Markdown, YouTubeVideo

device = torch.device('cuda:0')
print('Using device:', device, file=sys.stderr)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-41s985lg
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-41s985lg
#   Resolved https://github.com/openai/whisper.git to commit 248b6cb124225dd263bb9bd32d060b6517e067f8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230314) (2.0.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230314) (0.56.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230314) (1.22.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230314) (2.0.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230314) (4.65.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230314) (9.1.0)
# Collecting tiktoken==0.3.3 (from openai-whisper==20230314)
#   Downloading tiktoken-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 75.8 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken==0.3.3->openai-whisper==20230314) (2022.10.31)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken==0.3.3->openai-whisper==20230314) (2.27.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->openai-whisper==20230314) (3.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->openai-whisper==20230314) (3.12.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->openai-whisper==20230314) (16.0.5)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper==20230314) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper==20230314) (67.7.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20230314) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20230314) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20230314) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20230314) (3.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.3.3->openai-whisper==20230314) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.3.3->openai-whisper==20230314) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.3.3->openai-whisper==20230314) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.3.3->openai-whisper==20230314) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper==20230314) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper==20230314) (1.3.0)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20230314-py3-none-any.whl size=798075 sha256=c42933e599f4a67acf9c2594cba3a29505babb8d514c4428524b529860c125d0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-bghlrm_b/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# Installing collected packages: tiktoken, openai-whisper
# Successfully installed openai-whisper-20230314 tiktoken-0.3.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yt-dlp
#   Downloading yt_dlp-2023.3.4-py2.py3-none-any.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 71.6 MB/s eta 0:00:00
# Collecting mutagen (from yt-dlp)
#   Downloading mutagen-1.46.0-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 27.3 MB/s eta 0:00:00
# Collecting pycryptodomex (from yt-dlp)
#   Downloading pycryptodomex-3.18.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 62.1 MB/s eta 0:00:00
# Collecting websockets (from yt-dlp)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2022.12.7)
# Collecting brotli (from yt-dlp)
#   Downloading Brotli-1.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 91.2 MB/s eta 0:00:00
# Installing collected packages: brotli, websockets, pycryptodomex, mutagen, yt-dlp
# Successfully installed brotli-1.0.9 mutagen-1.46.0 pycryptodomex-3.18.0 websockets-11.0.3 yt-dlp-2023.3.4
# Using device: cuda:0

# %%
#@markdown # **Optional:** Save data in Google Drive 💾
#@markdown Enter a Google Drive path and run this cell if you want to store the results inside Google Drive.

# Uncomment to copy generated images to drive, faster than downloading directly from colab in my experience.
from google.colab import drive
drive_mount_path = Path("/") / "content" / "drive"
drive.mount(str(drive_mount_path))
drive_mount_path /= "My Drive"
#@markdown ---
drive_path = "Colab Notebooks/Whisper Youtube" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change your Google Drive path.**

drive_whisper_path = drive_mount_path / Path(drive_path.lstrip("/"))
drive_whisper_path.mkdir(parents=True, exist_ok=True)

# %%
#@markdown # **Model selection** 🧠

#@markdown As of the first public release, there are 4 pre-trained options to play with:

#@markdown |  Size  | Parameters | English-only model | Multilingual model | Required VRAM | Relative speed |
#@markdown |:------:|:----------:|:------------------:|:------------------:|:-------------:|:--------------:|
#@markdown |  tiny  |    39 M    |     `tiny.en`      |       `tiny`       |     ~1 GB     |      ~32x      |
#@markdown |  base  |    74 M    |     `base.en`      |       `base`       |     ~1 GB     |      ~16x      |
#@markdown | small  |   244 M    |     `small.en`     |      `small`       |     ~2 GB     |      ~6x       |
#@markdown | medium |   769 M    |    `medium.en`     |      `medium`      |     ~5 GB     |      ~2x       |
#@markdown | large  |   1550 M   |        N/A         |      `large`       |    ~10 GB     |       1x       |

#@markdown ---
Model = 'medium' #@param ['tiny.en', 'tiny', 'base.en', 'base', 'small.en', 'small', 'medium.en', 'medium', 'large']
#@markdown ---
#@markdown **Run this cell again if you change the model.**

whisper_model = whisper.load_model(Model)

if Model in whisper.available_models():
    display(Markdown(
        f"**{Model} model is selected.**"
    ))
else:
    display(Markdown(
        f"**{Model} model is no longer available.**<br /> Please select one of the following:<br /> - {'<br /> - '.join(whisper.available_models())}"
    ))
# Out:
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:15<00:00, 101MiB/s]
# **medium model is selected.**

# %%
#@markdown # **Video selection** 📺

#@markdown Enter the URL of the Youtube video you want to transcribe, wether you want to save the audio file in your Google Drive, and run the cell.

Type = "Youtube video or playlist" #@param ['Youtube video or playlist', 'Google Drive']
#@markdown ---
#@markdown #### **Youtube video or playlist**
URL = "https://www.youtube.com/watch?v=J0HVwnOS0Wg&t=1305s" #@param {type:"string"}
# store_audio = True #@param {type:"boolean"}
#@markdown ---
#@markdown #### **Google Drive video, audio (mp4, wav), or folder containing video and/or audio files**
video_path = "Colab Notebooks/transcription/my_video.mp4" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change the video.**

video_path_local_list = []

if Type == "Youtube video or playlist":
    
    ydl_opts = {
        'format': 'm4a/bestaudio/best',
        'outtmpl': '%(id)s.%(ext)s',
        # ℹ️ See help(yt_dlp.postprocessor) for a list of available Postprocessors and their arguments
        'postprocessors': [{  # Extract audio using ffmpeg
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'wav',
        }]
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        error_code = ydl.download([URL])
        list_video_info = [ydl.extract_info(URL, download=False)]
        
    for video_info in list_video_info:
        video_path_local_list.append(Path(f"{video_info['id']}.wav"))

elif Type == "Google Drive":
    # video_path_drive = drive_mount_path / Path(video_path.lstrip("/"))
    video_path = drive_mount_path / Path(video_path.lstrip("/"))
    if video_path.is_dir():
        for video_path_drive in video_path.glob("**/*"):
            if video_path_drive.is_file():
                display(Markdown(f"**{str(video_path_drive)} selected for transcription.**"))
            elif video_path_drive.is_dir():
                display(Markdown(f"**Subfolders not supported.**"))
            else:
                display(Markdown(f"**{str(video_path_drive)} does not exist, skipping.**"))
            video_path_local = Path(".").resolve() / (video_path_drive.name)
            shutil.copy(video_path_drive, video_path_local)
            video_path_local_list.append(video_path_local)
    elif video_path.is_file():
        video_path_local = Path(".").resolve() / (video_path.name)
        shutil.copy(video_path, video_path_local)
        video_path_local_list.append(video_path_local)
        display(Markdown(f"**{str(video_path)} selected for transcription.**"))
    else:
        display(Markdown(f"**{str(video_path)} does not exist.**"))

else:
    raise(TypeError("Please select supported input type."))

for video_path_local in video_path_local_list:
    if video_path_local.suffix == ".mp4":
        video_path_local = video_path_local.with_suffix(".wav")
        result  = subprocess.run(["ffmpeg", "-i", str(video_path_local.with_suffix(".mp4")), "-vn", "-acodec", "pcm_s16le", "-ar", "16000", "-ac", "1", str(video_path_local)])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=J0HVwnOS0Wg&t=1305s
# [youtube] J0HVwnOS0Wg: Downloading webpage
# [youtube] J0HVwnOS0Wg: Downloading android player API JSON
# [info] J0HVwnOS0Wg: Downloading 1 format(s): 140
# [dashsegments] Total fragments: 6
# [download] Destination: J0HVwnOS0Wg.m4a
# [download] 100% of   59.40MiB in 00:00:21 at 2.76MiB/s
# [FixupM4a] Correcting container of "J0HVwnOS0Wg.m4a"
# [ExtractAudio] Destination: J0HVwnOS0Wg.wav
# Deleting original file J0HVwnOS0Wg.m4a (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=J0HVwnOS0Wg&t=1305s
# [youtube] J0HVwnOS0Wg: Downloading webpage
# [youtube] J0HVwnOS0Wg: Downloading android player API JSON

# %%
#@markdown # **Run the model** 🚀

#@markdown Run this cell to execute the transcription of the video. This can take a while and very based on the length of the video and the number of parameters of the model selected above.

#@markdown ## **Parameters** ⚙️

#@markdown ### **Behavior control**
#@markdown ---
language = "English" #@param ['Auto detection', 'Afrikaans', 'Albanian', 'Amharic', 'Arabic', 'Armenian', 'Assamese', 'Azerbaijani', 'Bashkir', 'Basque', 'Belarusian', 'Bengali', 'Bosnian', 'Breton', 'Bulgarian', 'Burmese', 'Castilian', 'Catalan', 'Chinese', 'Croatian', 'Czech', 'Danish', 'Dutch', 'English', 'Estonian', 'Faroese', 'Finnish', 'Flemish', 'French', 'Galician', 'Georgian', 'German', 'Greek', 'Gujarati', 'Haitian', 'Haitian Creole', 'Hausa', 'Hawaiian', 'Hebrew', 'Hindi', 'Hungarian', 'Icelandic', 'Indonesian', 'Italian', 'Japanese', 'Javanese', 'Kannada', 'Kazakh', 'Khmer', 'Korean', 'Lao', 'Latin', 'Latvian', 'Letzeburgesch', 'Lingala', 'Lithuanian', 'Luxembourgish', 'Macedonian', 'Malagasy', 'Malay', 'Malayalam', 'Maltese', 'Maori', 'Marathi', 'Moldavian', 'Moldovan', 'Mongolian', 'Myanmar', 'Nepali', 'Norwegian', 'Nynorsk', 'Occitan', 'Panjabi', 'Pashto', 'Persian', 'Polish', 'Portuguese', 'Punjabi', 'Pushto', 'Romanian', 'Russian', 'Sanskrit', 'Serbian', 'Shona', 'Sindhi', 'Sinhala', 'Sinhalese', 'Slovak', 'Slovenian', 'Somali', 'Spanish', 'Sundanese', 'Swahili', 'Swedish', 'Tagalog', 'Tajik', 'Tamil', 'Tatar', 'Telugu', 'Thai', 'Tibetan', 'Turkish', 'Turkmen', 'Ukrainian', 'Urdu', 'Uzbek', 'Valencian', 'Vietnamese', 'Welsh', 'Yiddish', 'Yoruba']
#@markdown > Language spoken in the audio, use `Auto detection` to let Whisper detect the language.
#@markdown ---
verbose = 'Live transcription' #@param ['Live transcription', 'Progress bar', 'None']
#@markdown > Whether to print out the progress and debug messages.
#@markdown ---
output_format = 'txt' #@param ['txt', 'vtt', 'srt', 'tsv', 'json', 'all']
#@markdown > Type of file to generate to record the transcription.
#@markdown ---
task = 'transcribe' #@param ['transcribe', 'translate']
#@markdown > Whether to perform X->X speech recognition (`transcribe`) or X->English translation (`translate`).
#@markdown ---

#@markdown <br/>

#@markdown ### **Optional: Fine tunning** 
#@markdown ---
temperature = 0.15 #@param {type:"slider", min:0, max:1, step:0.05}
#@markdown > Temperature to use for sampling.
#@markdown ---
temperature_increment_on_fallback = 0.2 #@param {type:"slider", min:0, max:1, step:0.05}
#@markdown > Temperature to increase when falling back when the decoding fails to meet either of the thresholds below.
#@markdown ---
best_of = 5 #@param {type:"integer"}
#@markdown > Number of candidates when sampling with non-zero temperature.
#@markdown ---
beam_size = 8 #@param {type:"integer"}
#@markdown > Number of beams in beam search, only applicable when temperature is zero.
#@markdown ---
patience = 1.0 #@param {type:"number"}
#@markdown > Optional patience value to use in beam decoding, as in [*Beam Decoding with Controlled Patience*](https://arxiv.org/abs/2204.05424), the default (1.0) is equivalent to conventional beam search.
#@markdown ---
length_penalty = -0.05 #@param {type:"slider", min:-0.05, max:1, step:0.05}
#@markdown > Optional token length penalty coefficient (alpha) as in [*Google's Neural Machine Translation System*](https://arxiv.org/abs/1609.08144), set to negative value to uses simple length normalization.
#@markdown ---
suppress_tokens = "-1" #@param {type:"string"}
#@markdown > Comma-separated list of token ids to suppress during sampling; '-1' will suppress most special characters except common punctuations.
#@markdown ---
initial_prompt = "" #@param {type:"string"}
#@markdown > Optional text to provide as a prompt for the first window.
#@markdown ---
condition_on_previous_text = True #@param {type:"boolean"}
#@markdown > if True, provide the previous output of the model as a prompt for the next window; disabling may make the text inconsistent across windows, but the model becomes less prone to getting stuck in a failure loop.
#@markdown ---
fp16 = True #@param {type:"boolean"}
#@markdown > whether to perform inference in fp16.
#@markdown ---
compression_ratio_threshold = 2.4 #@param {type:"number"}
#@markdown > If the gzip compression ratio is higher than this value, treat the decoding as failed.
#@markdown ---
logprob_threshold = -1.0 #@param {type:"number"}
#@markdown > If the average log probability is lower than this value, treat the decoding as failed.
#@markdown ---
no_speech_threshold = 0.6 #@param {type:"slider", min:-0.0, max:1, step:0.05}
#@markdown > If the probability of the <|nospeech|> token is higher than this value AND the decoding has failed due to `logprob_threshold`, consider the segment as silence.
#@markdown ---

verbose_lut = {
    'Live transcription': True,
    'Progress bar': False,
    'None': None
}

args = dict(
    language = (None if language == "Auto detection" else language),
    verbose = verbose_lut[verbose],
    task = task,
    temperature = temperature,
    temperature_increment_on_fallback = temperature_increment_on_fallback,
    best_of = best_of,
    beam_size = beam_size,
    patience=patience,
    length_penalty=(length_penalty if length_penalty>=0.0 else None),
    suppress_tokens=suppress_tokens,
    initial_prompt=(None if not initial_prompt else initial_prompt),
    condition_on_previous_text=condition_on_previous_text,
    fp16=fp16,
    compression_ratio_threshold=compression_ratio_threshold,
    logprob_threshold=logprob_threshold,
    no_speech_threshold=no_speech_threshold
)

temperature = args.pop("temperature")
temperature_increment_on_fallback = args.pop("temperature_increment_on_fallback")
if temperature_increment_on_fallback is not None:
    temperature = tuple(np.arange(temperature, 1.0 + 1e-6, temperature_increment_on_fallback))
else:
    temperature = [temperature]

if Model.endswith(".en") and args["language"] not in {"en", "English"}:
    warnings.warn(f"{Model} is an English-only model but receipted '{args['language']}'; using English instead.")
    args["language"] = "en"

for video_path_local in video_path_local_list:
    display(Markdown(f"### {video_path_local}"))

    video_transcription = whisper.transcribe(
        whisper_model,
        str(video_path_local),
        temperature=temperature,
        **args,
    )

    # Save output
    whisper.utils.get_writer(
        output_format=output_format,
        output_dir=video_path_local.parent
    )(
        video_transcription,
        str(video_path_local.stem),
        options=dict(
            highlight_words=False,
            max_line_count=None,
            max_line_width=None,
        )
    )
    try:
        if output_format=="all":
            for ext in ('txt', 'vtt', 'srt', 'tsv', 'json'):
                transcript_file_name = video_path_local.stem + "." + ext
                shutil.copy(
                    video_path_local.parent / transcript_file_name,
                    drive_whisper_path / transcript_file_name
                )
                display(Markdown(f"**Transcript file created: {drive_whisper_path / transcript_file_name}**"))
        else:
            transcript_file_name = video_path_local.stem + "." + output_format
            shutil.copy(
                video_path_local.parent / transcript_file_name,
                drive_whisper_path / transcript_file_name
            )
            display(Markdown(f"**Transcript file created: {drive_whisper_path / transcript_file_name}**"))

    except:
        display(Markdown(f"**Transcript file created: {transcript_local_path}**"))
# Out:
# ### J0HVwnOS0Wg.wav
# [00:00.000 --> 00:11.720]  So, I was, it was a very odd situation. I did my very first platform at WPPI two years
# [00:11.720 --> 00:19.920]  ago and I stood up on stage and my text, and you introduce your platform and there's 350
# [00:19.920 --> 00:25.520]  people, it was my first platform, I had a small room, and 250 people and my text went
# [00:25.520 --> 00:34.720]  off and I silenced the phone and didn't read the text and I turned, just a millisecond,
# [00:34.720 --> 00:38.080]  I turned away from it and I was like, I don't know why, I didn't read it, I just went,
# [00:38.080 --> 00:42.360]  I've got to introduce myself and then I stepped like this and I said, my name is Sue Bryce
# [00:42.360 --> 00:46.880]  and I'm a portrait photographer and everyone clapped and I did my two hour platform and
# [00:46.880 --> 00:53.680]  it was just a crazy experience to be in front of a big crowd and be in Vegas and present
# [00:53.680 --> 00:59.720]  this platform and it was really huge and when I finished, all of my friends were sort of
# [00:59.720 --> 01:03.280]  sitting down the front, I'll tell you why it's making me all funny, sitting down the
# [01:03.280 --> 01:06.640]  front and they were all looking at me like this and I was like, did you enjoy that? And
# [01:06.640 --> 01:14.160]  they're like, there's been a devastating earthquake in New Zealand at Christchurch and that's
# [01:14.160 --> 01:19.680]  where my parents were, so luckily my parents were safe and that all happened, the text
# [01:19.720 --> 01:24.360]  that I got was that there's been an earthquake right now and had I read that, I would have
# [01:24.360 --> 01:30.240]  been standing in front of all these people. It upsets me because I remember that moment
# [01:30.240 --> 01:35.840]  of just wondering if my parents were alive and I couldn't get through to them on the
# [01:35.840 --> 01:40.240]  phone so I didn't get through to them for another two hours and very luckily they were
# [01:40.240 --> 01:45.500]  alive. Anyway, I have lots of dear friends that live in Christchurch and I remember going
# [01:45.500 --> 01:51.660]  from Vegas to New York that week and I was in Times Square and I saw this big billboard
# [01:51.660 --> 01:55.900]  come across and it said all the people that had died in Christchurch, New Zealand and
# [01:55.900 --> 02:00.500]  I remember reading it on this billboard in Times Square and just thinking how far away
# [02:00.500 --> 02:06.620]  I was from home and how close my parents were to that. But anyway, I had lots of friends
# [02:06.620 --> 02:10.220]  who are photographers and I've known for years that have lived and worked there and two of
# [02:10.340 --> 02:15.380]  my absolute favourites are Joe Grams and Johan van Kahn and they actually have one of the
# [02:15.380 --> 02:20.380]  most beautiful studios that I have ever seen. Now I built a beautiful studio and I know
# [02:20.380 --> 02:24.860]  that my studio is better than most people's and their studio was so beautiful and they
# [02:24.860 --> 02:31.860]  lost that and their home in one morning in Christchurch. So fast forward to two years,
# [02:32.140 --> 02:36.860]  my parents have left Christchurch because I made them leave, I paid for them to go because
# [02:36.860 --> 02:41.940]  my parents, when I saw them after four months of working and living in Christchurch, I saw
# [02:41.940 --> 02:45.060]  them and they'd put on weight and they looked really unhappy and I said to mum and dad,
# [02:45.060 --> 02:50.380]  what's up? And they just said, it's so depressing here. Every day there's more earthquakes and
# [02:50.380 --> 02:56.540]  every day people are evacuating and the town centre has never been brought back and it's
# [02:56.540 --> 03:03.540]  devastation at its long-term level. And throughout losing their home and their studio, these
# [03:03.740 --> 03:08.600]  two kept their business going and stayed in Christchurch with their baby daughter because
# [03:08.600 --> 03:15.300]  they decided that they kept their business alive because of Joe's, she said, loyal client
# [03:15.300 --> 03:21.100]  base. That people still ring her for photographs even through this time. They are still getting
# [03:21.100 --> 03:25.180]  business, still rocking their business. So as we talk about fear and loss in the next
# [03:25.180 --> 03:29.700]  hour and a half, it just occurred to me that the greatest story of fear and loss is actually
# [03:29.700 --> 03:34.380]  sitting in my audience today. And anything that you could possibly confront wouldn't
# [03:34.380 --> 03:39.220]  be as bad as what these two have just discovered about themselves in the last two years without
# [03:39.220 --> 03:43.940]  insurance being paid, without, you know, and that sort of devastation. But not only the
# [03:43.940 --> 03:49.420]  devastation but the energy in their community, of a community that is being destroyed and
# [03:49.420 --> 03:54.660]  is being rebuilt. And I know there are other communities here, Katrina and et cetera, destroyed
# [03:54.660 --> 03:58.460]  and that people are rebuilding all the time and that they still have effects. But what
# [03:58.500 --> 04:02.300]  I do want to say is one thing. I actually just wanted to shout out that they were here
# [04:02.300 --> 04:06.660]  and then everyone said, you know, let's meet them. So I asked Joe and Johanna if they'd
# [04:06.660 --> 04:09.980]  like to come up and talk to me. So come and talk to me for a minute. I was trying to do
# [04:09.980 --> 04:16.580]  that. I was trying to do that. I was trying to do that without looking at it because I
# [04:16.580 --> 04:22.300]  knew that I'd cry if I looked at them. These two are significantly beautiful photographers.
# [04:22.300 --> 04:26.180]  We're going to post their website for you on the chat so that you can see it. It's
# [04:26.180 --> 04:33.180]  a difficult website to remember, to spell out. Moda Photographica. So it's Moda Photographica
# [04:33.540 --> 04:39.540]  but for some reason when we had the building we wanted to have the European influence so
# [04:39.540 --> 04:45.100]  we changed. Well it was a European building though. It was so gothic. We had to go with
# [04:45.100 --> 04:49.460]  a brand that suited the building and that's why it was Moda Photographica with Fs instead
# [04:49.460 --> 04:56.460]  of Ph. Yeah. Fantastic. So I just want to... So Moda, M-O-D-A and then Photographica, F-O-T-O-G-R-A-F-I-C-A.
# [05:04.980 --> 05:11.980]  And it means .co.nz. Yeah so we don't dot com we dot co.nz there. And it means a way
# [05:12.580 --> 05:18.540]  of drawing light. That's the meaning behind it. Beautiful. Thank you. So both Joe and
# [05:18.540 --> 05:22.740]  Johan met as photographers, married as photographers, fell in love as photographers. They're both
# [05:22.740 --> 05:27.060]  award winning photographers. They're both judges internationally. They both win in both
# [05:27.060 --> 05:31.300]  New Zealand and Australia consistently. But if I can say one thing about both of them,
# [05:31.300 --> 05:34.820]  both of them are great educators. Both of them are great speakers. Both of them are
# [05:34.820 --> 05:40.660]  incredible photographers. But very few photographers that I meet bring a level of beauty and artistry
# [05:40.660 --> 05:46.440]  to the work that these two do. So please enjoy their website. And I just thought as we go
# [05:46.440 --> 05:50.840]  into this segment I would like to introduce you to these two people. Because Joe rung
# [05:50.840 --> 05:56.320]  me a month ago and she said I've applied for your audience. I'm coming over. And so she
# [05:56.320 --> 06:02.240]  said the struggle here is just too much. And I really know that if I come over and I see
# [06:02.240 --> 06:09.240]  you and I sit in your audience that you're going to kick my ass. And do you know what
# [06:10.240 --> 06:16.620]  that means? To have your ass kicked in an economy that she's living in and the devastation
# [06:16.620 --> 06:20.020]  that they're living in, to still want to run a business there and to still think that
# [06:20.020 --> 06:23.980]  there's hope for that and to still want to turn your own attitude and your own thoughts
# [06:23.980 --> 06:29.840]  and your own everything around. That's survival at its purest form. But the truth is that's
# [06:29.840 --> 06:34.140]  a choice. You could dwell on it or you could overcome it. And you know what? I think that
# [06:34.140 --> 06:38.620]  they will because everything they do is beautiful. So I should let them talk. I just can't
# [06:38.620 --> 06:45.620]  stop talking. Thank you Sue. You made me cry when I was standing back there and remembering
# [06:47.120 --> 06:54.120]  that day in February. Just so you know I actually watched, when you say that, I watched a movie.
# [06:55.880 --> 07:01.780]  So I met a guy that filmed it. He was in the earthquake and he's a film maker and he picked
# [07:01.780 --> 07:06.980]  up Logan McMillan and he's got footage on YouTube and he picked up his camera and went
# [07:06.980 --> 07:13.980]  straight out. But when he did the presentation at NZIBP, he cut in a live recording of a
# [07:14.740 --> 07:19.700]  woman that was doing a radio interview. She was interviewing someone live on radio and
# [07:19.700 --> 07:24.140]  the earthquake hit and you can hear the sound. And he cut all the visual footage and all
# [07:24.140 --> 07:30.660]  you hear is the sound of the earthquake and her reaction. And it is, in that moment, oh
# [07:30.740 --> 07:37.000]  gosh it's so incredible to think that nature can take away from you and heartbeat what
# [07:37.000 --> 07:42.780]  you could build a lifetime. And I remember that sitting there and hearing the sound and
# [07:42.780 --> 07:48.060]  I got the impact just by the imagery of what my parents were experiencing when I was a
# [07:48.060 --> 07:52.980]  world away from them in Vegas. So that morning I know when everyone talks about it they talk
# [07:52.980 --> 07:59.980]  about it the same way. For us it was very difficult as well because not only did our
# [08:00.060 --> 08:05.300]  buildings start falling down, we were a hill away from each other. Jo was on the other
# [08:05.300 --> 08:10.460]  side of the hill and the only way through was through a tunnel that they closed. So
# [08:10.460 --> 08:17.460]  she decided to walk over. I found five muscly buoys. Who had the baby? I did. And all I
# [08:21.500 --> 08:26.540]  had was rice bubbles to feed her up on the hill. She would have been happy with rice
# [08:26.580 --> 08:32.900]  bubbles. But it's amazing how these things change you and one of the really good things
# [08:32.900 --> 08:36.460]  to come out of it and you have to look at the good things because you can't dwell on
# [08:36.460 --> 08:41.060]  the loss and the things that went bad for you. One of the really good things about it
# [08:41.060 --> 08:46.900]  was the opportunity to look at ourselves from out here somewhere and say well we can't drag
# [08:46.900 --> 08:50.820]  any of that with us because it doesn't exist anymore. And if we were going to start our
# [08:50.820 --> 08:55.820]  lives as new people, as photographers, what would be the most amazing thing we could do?
# [08:55.820 --> 08:59.780]  And that was perhaps the most powerful thing that we could take from it. And it's the sort
# [08:59.780 --> 09:04.940]  of thing that is important for everybody I think. What was that for you? The thing that
# [09:04.940 --> 09:10.700]  we could take? Yeah. It was actually being the ability to look at ourselves almost separate
# [09:10.700 --> 09:14.980]  from ourselves and say look at those people down there, what should they do in this circumstance
# [09:14.980 --> 09:19.060]  and how can they be the best at what they can do rather than say well we've got all
# [09:19.060 --> 09:23.860]  these encumbrances that you drag around with you, all the things that you gather up and
# [09:23.860 --> 09:27.860]  you say I can't change because I have these things on my shoulders that hold me down.
# [09:27.860 --> 09:33.700]  Yeah, baggage. And how did it change you as a photographer? Did it change you as a photographer?
# [09:33.700 --> 09:38.380]  Does it make you value seeing people's family portraits destroyed forever, never to be brought
# [09:38.380 --> 09:45.260]  back to them? I think the biggest thing for me in how I take my photographs is I have
# [09:45.260 --> 09:52.420]  a very loyal following of clients and I shoot over a period of time. I would take a family
# [09:52.420 --> 09:59.740]  right through pregnancy or a wedding pregnancy, first born, second born, kids, all the way
# [09:59.740 --> 10:07.020]  through. And for me, one of the latest projects was finishing off a two year project for a
# [10:07.020 --> 10:12.980]  client and just going back from when he was a newborn and that was before the earthquake
# [10:12.980 --> 10:20.940]  to seeing this kid now and that's in an album and it's the most precious thing that I can
# [10:20.940 --> 10:26.460]  give a family is those memories. Thank you. I just wanted you all to meet them and enjoy
# [10:26.460 --> 10:35.620]  their website and out there enjoy that. Just to let you know, the people in the chat room
# [10:35.620 --> 10:43.540]  have been looking and the wedding portraits are amazing. Wow, awesome images there. They're
# [10:43.540 --> 10:48.460]  amazed by your work. So congratulations. It is beautiful. Thank you for coming. Thank
# [10:48.460 --> 11:00.500]  you very much. Absolutely. I'll always find ways to get Kiwi accents up here. Let's talk
# [11:00.500 --> 11:04.420]  about everything that's going to get in your way. Okay, I've laid out the challenges. I'm
# [11:04.420 --> 11:08.060]  going to talk about them again when I wrap it up this afternoon. I've laid out how to
# [11:08.060 --> 11:13.300]  make money. I've laid out how to get different avenues to marketing, multiple different avenues
# [11:13.300 --> 11:17.780]  to marketing. I've laid out how to open your mind, how to open your creativity. I've laid
# [11:18.180 --> 11:22.260]  out how to look at your business blocks and see where you suffer, where you fail, where you succeed.
# [11:22.260 --> 11:27.900]  I've asked you to confront where you fail and decide in that moment whether you need to confront
# [11:27.900 --> 11:32.140]  it further or whether you need to let it go and outsource it. I told you to write a hate list.
# [11:32.140 --> 11:36.340]  We're going to go back through that this afternoon. But before I do, I want to address this one
# [11:36.340 --> 11:42.260]  incredible experience that I had about three weeks ago when I was sitting at home and I had a fearful
# [11:42.420 --> 11:50.780]  moment in my personal self and I put this post on In Bed With Sue, which is a private Facebook
# [11:50.780 --> 11:55.820]  group dedicated to just becoming better glamour photographers. There's about seven and a half
# [11:55.820 --> 12:00.980]  thousand people in it and join it if you want to, In Bed With Sue, on Facebook and you have to get
# [12:00.980 --> 12:06.940]  invited. It's a closed group. I put this when I was talking about marketing on Saturday, so that
# [12:06.940 --> 12:15.300]  was after Hayley's showreels course. You are all very creative and very few of you get excited
# [12:15.300 --> 12:21.280]  about marketing. I don't understand that. And then I remembered why I never got excited by
# [12:21.280 --> 12:27.740]  marketing because I knew where my block was. And you see the fear, the blocks and the cants and
# [12:27.740 --> 12:36.580]  the excuses. It occurred, I want you to name the thing that makes you walk away. I want you to
# [12:36.580 --> 12:43.820]  name the thing that makes you walk away from a phone call, from approaching a person and from
# [12:43.820 --> 12:50.300]  putting yourself out there. This is all I wrote. It's a Facebook thread. Okay, so that was January
# [12:50.300 --> 12:56.500]  the 29th and 1248 p.m. afternoon. Clearly, I should have been working, but I was sitting at
# [12:56.500 --> 13:03.220]  my table having a conversation with people on Facebook. And I will go first. That's what I
# [13:03.220 --> 13:10.060]  wrote. I want you to see how similar we all are, so keep it short. I have a solution. I just want
# [13:10.060 --> 13:22.700]  to hear it. That's what I wrote. I got 1,363 posts in an hour on that thread and I'll read some of
# [13:22.900 --> 13:30.380]  them to you. I started first. Rejection, not good enough. Nobody will pay for that. What you do is
# [13:30.380 --> 13:35.340]  not worth it. And then it just started. I don't deserve to be successful. Feeling inadequate,
# [13:35.340 --> 13:39.620]  too expensive. Everyone wants something for nothing. I'm not good enough. Skill isn't good
# [13:39.620 --> 13:44.620]  enough. I'm going to eff something up. No one will pay for it. You won't make money doing this.
# [13:44.620 --> 13:49.860]  Haven't been in the business long enough. Too shy. Too expensive. Not smart enough. Not smart
# [13:50.100 --> 13:53.380]  enough to do business. I don't know what I'm doing. If it were that easy, everybody would be good
# [13:53.380 --> 13:57.380]  at it. I don't look that glamorous. I'm not that beautiful. How am I to show their beauty if I don't
# [13:57.380 --> 14:02.100]  exude mine? They want everything for free. Too expensive. Nobody will pay for what I want. Ugly
# [14:02.100 --> 14:05.860]  style. Working from my garage. My work isn't good enough. I have too much to learn. Don't eat it
# [14:05.860 --> 14:09.940]  when I get better at posing. This lady must be crazy. Studio is in my garage. I don't have the
# [14:09.940 --> 14:14.420]  time. I'll lose my family. I'll look like... I don't even know what that is. So much of this
# [14:14.420 --> 14:18.580]  sounds familiar. Competition indeed. I'm scared of. I can't afford that. I need a makeup artist.
# [14:18.580 --> 14:24.100]  I'm fighting for space. Second guessing every decision I make. Joe Bloggs does it better. Hard
# [14:24.100 --> 14:29.540]  work. Never succeed. I have to do this other job that I hate. Or how will I support myself? Working
# [14:29.540 --> 14:33.940]  out the price for a product. My studio has a living room inside it. I think all my responses have been
# [14:33.940 --> 14:41.300]  said. My camera didn't cost over $2,000. I need a website and a logo. What if they don't like my
# [14:41.300 --> 14:44.820]  work? What if they don't like me? Someone else is better. Wish I had a better camera. No studio
# [14:44.820 --> 14:48.980]  props. Why try if you're going to fail anyway? You're not worth it. Your work is average.
# [14:49.540 --> 14:55.860]  Then something started to happen in this thread. You did what all human beings did. You started to
# [14:55.860 --> 15:01.460]  do. You started to blame others. You stopped taking responsibility of yourself. You told me
# [15:01.460 --> 15:07.460]  you went from your emotional responses to the market is failing. Too many photographers in the
# [15:07.460 --> 15:13.540]  industry. Too many shooting burns in the industry. They are not emotions people. That is blame and a
# [15:13.540 --> 15:22.100]  victim mentality and a negative block. So I jump on the thread and I say I don't care about what
# [15:22.100 --> 15:29.300]  you think of the industry. I asked you to tell me how you feel. Emotions only please. Just tell me
# [15:29.300 --> 15:36.580]  how you feel. And it went back again. I won't meet expectations. It's too scary. It's too expensive.
# [15:36.580 --> 15:41.540]  I'm waiting for the right time. The other person is better than me. It just keeps going and it
# [15:41.540 --> 15:47.220]  keeps going. Not the right city. I haven't been doing it long enough. And then again it turned
# [15:47.220 --> 15:53.940]  immediately into blame again. It just turns instantly into my competition is cheaper than I am.
# [15:55.780 --> 16:00.660]  Women don't value themselves in my area. There's no money in where I am. I'm from a small town.
# [16:00.660 --> 16:05.300]  None of those are emotions people. I asked you to tell me how you feel. And then it went back again.
# [16:05.300 --> 16:10.580]  So I stayed on the thread for the whole hour and I kept saying stop telling me what you think of
# [16:10.580 --> 16:16.420]  the industry and capitals and tell me how you feel. And then it would start again. Rejection.
# [16:16.420 --> 16:21.700]  I don't look good enough. I'm not good enough. I'm not good enough. Rejection. Criticism.
# [16:23.060 --> 16:25.140]  Somebody wrote the cow jumped over the moon.
# [16:30.980 --> 16:33.620]  Awesome Jaren. Just so you know we do have your Facebook page.
# [16:34.260 --> 16:39.140]  I'm not as good as everybody else and it keeps shifting. And every single time the thread went
# [16:39.140 --> 16:43.540]  through it would change and change and change and change. And then every single time it would go
# [16:43.540 --> 16:49.140]  back it would go to blame and blame and blame and blame. And I kept asking for emotion. I didn't
# [16:49.140 --> 16:55.300]  ask you to tell me what you think about yourself. I asked you to tell me how you feel about yourself.
# [16:55.300 --> 17:01.220]  And that is based purely on emotion. And when I keep putting up on that thread it's amazing.
# [17:01.220 --> 17:06.900]  When I keep putting up on that thread it's emotion. I need emotion. Stop it. I need emotion.
# [17:06.900 --> 17:11.060]  Stop telling me about this industry. I need emotion. And then finally it just kept coming
# [17:11.060 --> 17:17.220]  back to emotion. And then what it came down to is I'm just not good enough. I'm not good enough.
# [17:17.220 --> 17:22.580]  I'm not pretty enough. I'm not skinny enough. I'm not smart enough. I don't have as many things.
# [17:23.620 --> 17:27.780]  That was the bottom line for everybody over and over and over again. The bottom line
# [17:27.780 --> 17:33.700]  keep coming back to that. But the worst thing is the amount of people that tried to blame someone else.
# [17:35.700 --> 17:42.660]  Now I don't care if this segment of this workshop sits really hard with you. I don't care. I'm going
# [17:42.660 --> 17:48.260]  to challenge this on every level. I don't care if you think you're the best photographer in the
# [17:48.260 --> 17:52.660]  world or the best business person in the world. If you don't sort your attitude out you will get
# [17:52.660 --> 17:59.220]  nothing different in this world. It's that simple. I believe this so passionately that I'm going to
# [17:59.220 --> 18:05.380]  tell you why. Now I don't think I have the right personality. Fear of succeeding. I'm not pretty
# [18:05.380 --> 18:11.620]  enough. I'm not pretty enough. The most famous photographers in the world certainly aren't good
# [18:11.620 --> 18:16.260]  looking. I think the only good looking photographer I've ever seen is Christy Turlington. You know she
# [18:16.260 --> 18:20.740]  used to be a supermodel and now she's a photographer. Oh my god everybody's a photographer these days.
# [18:23.620 --> 18:28.340]  Like supermodel wasn't good enough. You know it's like when you write that on the form on the
# [18:28.340 --> 18:35.620]  plane Christy do you write photographer now or ex supermodel? You know I'm insecure. The fear of
# [18:35.620 --> 18:41.460]  someone saying no. The fear of failure. The fear of not being good enough. The fear of rejection.
# [18:41.460 --> 18:46.820]  The fear of being told I am nothing. The fear of being told I am not good enough. Not being
# [18:46.820 --> 18:52.340]  appreciated. Not being taken seriously. Not enough time. I will lose my momentum and quit if it gets
# [18:52.340 --> 18:57.540]  too tough. Too much watching. Too much not. Too much apathy. Too much fear. Too much can't leave
# [18:57.540 --> 19:04.180]  the house and then we're blaming again. You know so the bottom line for everybody came down to one
# [19:04.180 --> 19:09.940]  thing. I'm not worthy and I'm not good enough. You are not worthy to what? Make an income but you can
# [19:09.940 --> 19:14.660]  get a job that makes an income. So you go and get a job that earns you what? $400 a week and that's
# [19:14.660 --> 19:21.380]  what you think you're worth. So it's okay to accept a wage but not make your own income and then when
# [19:21.380 --> 19:25.540]  you leave that wage you go and start your business and you know what you do? You do what my two
# [19:25.540 --> 19:31.140]  photographers did. You create a business that turns over $400 a week because that in your mentality
# [19:31.140 --> 19:39.060]  is what you think you're worth. Bottom line. So it's okay to go and get a wage from somebody and
# [19:39.060 --> 19:43.540]  even better I've been an employee before it's okay to stay on Facebook for an hour when your boss
# [19:43.540 --> 19:48.420]  isn't there wasting a whole hour of his salary and trust me you don't get pissed off about that
# [19:48.420 --> 19:52.980]  until you're a boss. Then you find out your staff are doing it and then you remember you did it so
# [19:52.980 --> 20:01.540]  you have to let it go. So it's okay to rip him off and get your money every week and then complain
# [20:01.540 --> 20:09.540]  that it's not enough and it's your choice. Awesome. Cool rule right? You made that. So now go and start
# [20:09.540 --> 20:16.260]  your business and go take your wage I'm not good enough mentality go and rinse repeat and suffer.
# [20:17.220 --> 20:24.580]  Suffering your jocks. That's how it works. We do the same thing over and over again and we cry out
# [20:25.380 --> 20:31.380]  that it's not my fault. You know what's not your fault? A friggin earthquake. That's not your fault.
# [20:32.420 --> 20:39.700]  Your fault would be how you deal with it. You know and this is what I learned because I was the
# [20:39.860 --> 20:46.420]  biggest victim of them all and I reeked of it. Heart and soul.
# [20:48.260 --> 20:54.900]  I'm not ready to do this. I'm gonna get rejected. I'm too scared. Bumbling, stuttering, sounding like
# [20:54.900 --> 21:02.900]  an idiot. I'm afraid to ask for what I want for what I need. It just goes on and on and on and on
# [21:03.700 --> 21:06.580]  and every single one of them have the same bottom line.
# [21:08.420 --> 21:12.260]  And it just occurred to me that until I dealt with that I didn't change anything.
# [21:13.220 --> 21:18.260]  And so this has the same bottom line but trust me it gets broken up into many divisions so
# [21:18.260 --> 21:24.980]  you can own which one's yours and you can own it today. I hear a lot of people tell me about fear.
# [21:24.980 --> 21:30.020]  Nobody tells you how to get over it. You said to me yesterday when we broke you said everybody
# [21:30.020 --> 21:34.340]  tells you about building a business and be around successful people but nobody tells you
# [21:34.340 --> 21:39.620]  to identify the blocks like where they went wrong. Nobody tells you to identify your own blocks.
# [21:39.620 --> 21:43.940]  They all just tell you to like climb to the top of the hill right because at the top of the hill
# [21:43.940 --> 21:48.980]  the cherries are up there and then when you reach there it's sunshine and roses and butterflies
# [21:48.980 --> 21:55.460]  and it's a lie. It is a filthy dirty lie because every person who's even climbed that hill knows
# [21:55.460 --> 22:00.580]  the hill just keeps going and the bigger you get and the more successful you get the bigger your
# [22:00.580 --> 22:06.260]  hill gets. It's the same struggle. The trick is to not see it as a struggle but a journey or a
# [22:06.260 --> 22:10.180]  you know or an experience or gratitude or you know or many other things and I'm going to tell
# [22:10.180 --> 22:14.900]  you the answer to that. And everybody talks to me about fear and climbing the mountain but nobody
# [22:14.900 --> 22:19.780]  ever tells me how and you know and that's the thing that really bugged me. I used to sit there
# [22:19.780 --> 22:26.260]  and think we can discuss fear until the sun sets and it won't change the fact that I'm going to
# [22:26.260 --> 22:31.460]  wake up tomorrow and not be able to make a phone call in my business because I'm terrified. Why
# [22:31.460 --> 22:40.180]  am I terrified? I'm not terrified. I just don't think I'm worth it. I don't think I'm worth it.
# [22:40.180 --> 22:51.380]  That's heartbreaking isn't it? So I look at this thread and I get through it and I sit there and I
# [22:51.380 --> 22:57.940]  think to myself wow that comes down to our attitude and what we think and what we feel
# [22:58.660 --> 23:03.780]  and that just keeps going and going and going and I photographed it because I wanted to keep it
# [23:04.740 --> 23:13.380]  you know and I even like the bit where people said their fear is of success, their fear is
# [23:13.940 --> 23:18.820]  of losing success, their fear is their greatest fear is to never realise it
# [23:20.820 --> 23:25.220]  and wouldn't that be the definition of a sad life that you would get to the end of it and
# [23:25.220 --> 23:30.580]  never have realised it in any way shape or form because you were too afraid to ever confront it.
# [23:31.140 --> 23:35.060]  You know and it's and it's the best part is is right now I'm going to explain to you why it's
# [23:35.060 --> 23:43.780]  so fake and artificial and why it doesn't actually exist at all. So once I get to here this to me
# [23:43.780 --> 23:50.260]  were the the key words I've experienced every one of them failure what is failure we failed and then
# [23:50.260 --> 23:58.020]  we climb back up again it's called life you get a polarity the more you love the more you lose
# [23:58.980 --> 24:04.820]  do you understand that to love someone so greatly and to lose them means you grieve as greatly as
# [24:04.820 --> 24:10.340]  you love them to love no one at all would mean no grief but that's how you know yourself that is the
# [24:10.340 --> 24:15.700]  polarity of life with every good comes bad with every love comes grief and I can guarantee that
# [24:15.700 --> 24:20.660]  when you're experiencing a high there will be a low that matches it that is called the polarity
# [24:20.660 --> 24:26.740]  that we exist in yin yang you know all of it it's just that's that's the rules I know that when you
# [24:26.740 --> 24:32.180]  lose someone and you've loved them greatly that the only thing you can do is grieve for as long as
# [24:32.180 --> 24:37.620]  you need to and then focus on how much you love them because if you focus on what you don't have
# [24:38.340 --> 24:44.980]  then that's where you will be locked in your grief and I know that if you get 50 50 of everything
# [24:44.980 --> 24:51.700]  including you know loss and success and failure then it stands to reason that across the board
# [24:51.700 --> 24:55.060]  the only reason you don't sit in the middle is because you're choosing to dwell on one side
# [24:55.060 --> 25:00.980]  of the other you choose that okay you choose that you choose that if you make your weakness
# [25:00.980 --> 25:05.540]  your greatest strength that it stands to reason that you can go and take something as devastating
# [25:05.540 --> 25:11.060]  as losing your entire business and rebuilding it and you can make that your greatest strength
# [25:11.940 --> 25:17.060]  and then you can empower yourself and others by how you rebuilt it and what you learned from it
# [25:17.060 --> 25:22.980]  that will make you more powerful than anybody else because you will be working from your heart
# [25:22.980 --> 25:31.620]  and your soul I know that apathy is non-action and apathy stops you from doing anything and no
# [25:31.620 --> 25:39.380]  matter how afraid you are or how afraid you think you are it means absolutely nothing if you don't
# [25:39.380 --> 25:46.500]  take action now a few years ago a book came out called the secret here's the thing abundance
# [25:46.580 --> 25:53.540]  didn't know it was a secret but read the book and went yeah all right I'm already of an
# [25:53.540 --> 25:59.780]  abundant mentality so I was really interested to read it and one of the things that I saw happen
# [25:59.780 --> 26:03.940]  afterwards was everybody lay on the couch and tried to manifest the Ferrari
# [26:06.260 --> 26:11.700]  and that's that's the magical thing about manifestation you can sit on a chair and look
# [26:11.700 --> 26:18.980]  at a door and you can will it to open I will let to open I manifest that door opens that door
# [26:18.980 --> 26:24.260]  will open that door will open for me the door is not opening it's not going to open it's never
# [26:24.260 --> 26:30.020]  going to open why am I trying to will the door to open and yet if you said I manifest this door to
# [26:30.020 --> 26:34.900]  open and a million different doors for me an opportunity and you got up and you actually
# [26:34.900 --> 26:39.300]  touched the handle and opened it and then walked through it you'll find you're in a corridor with
# [26:39.300 --> 26:44.420]  50 other doors and you can choose which one you walk through so you actually have to get up and
# [26:44.420 --> 26:49.700]  do something about it but you have to do that you have to get up and walk across the room with no
# [26:49.700 --> 26:56.980]  fear now what if your fear wasn't fear at all because if you're in a white room and there's
# [26:56.980 --> 27:05.780]  no tigers no no biting dogs no nails on the floor no chainsaw massacre standing between you and the
# [27:05.780 --> 27:13.220]  door what are you afraid of there is no flight or fight there there's no need to run there's no need
# [27:13.220 --> 27:20.500]  to cry there's no need to fight so when you tell me you're afraid to open the door I don't actually
# [27:20.500 --> 27:26.340]  believe that anymore in fact I don't think fear exists I discovered when I read that book about
# [27:26.340 --> 27:31.620]  self-hate that the reason that you stop getting up and opening that door is because the voice of
# [27:31.620 --> 27:40.820]  self-hate is so strong it tells you to sit back down and be nothing and you listen to it you choose
# [27:40.820 --> 27:47.460]  in that moment to listen to the voice in your head that says sit down you're a worthless piece
# [27:48.020 --> 27:55.060]  of shit and you do because you've been listening to it for years and it's a little voice some people
# [27:55.060 --> 27:59.940]  have it bigger I have a big self-hate voice some people have a huge self-hate voice some people
# [27:59.940 --> 28:05.380]  are controlled by that voice they don't even know it and that will stop you from opening that door
# [28:05.380 --> 28:12.020]  it will stop you from getting up from the couch so now I know this I know there's no fear I stand
# [28:12.020 --> 28:18.100]  up and I say there is no fear in my body because I'm safe right now I don't have a fight or flight
# [28:18.100 --> 28:22.900]  response right now or adrenaline in my body therefore as I step forward I hear the voice of
# [28:22.900 --> 28:29.700]  self-hate oh it's crippling me and it hurts and it just says stuff and it just it's my voice and
# [28:29.700 --> 28:33.460]  it's my belief and I have to walk across this room and I every step I take it's going to be
# [28:33.460 --> 28:39.780]  stronger and stronger and then I just sit there and I go ah I get that voice stop and it stops
# [28:40.980 --> 28:44.660]  and then I'm like I don't choose to hate myself anymore that was an old pattern
# [28:44.660 --> 28:48.820]  and whatever I whatever I did that for whatever your reason for doing it please don't tell me
# [28:48.820 --> 28:54.980]  that story the reason I'm in so much self-hate like stop re-energizing the self-hate for god's
# [28:54.980 --> 29:00.340]  sake just acknowledge it acknowledge it went through a bad patch got a bit of self-hate going on
# [29:01.700 --> 29:07.220]  dealing with that now you know it's not emotional you've made it emotional you've made it your life
# [29:07.220 --> 29:11.060]  voice you've made it you know like this was my bad patch you don't need to hear about it we've all
# [29:11.060 --> 29:15.300]  had a bad patch right mine was really big though mine was more important than yours don't you
# [29:15.300 --> 29:21.940]  understand I have to stay with self-hate because mine actually isn't self-hate mine was traumatic
# [29:21.940 --> 29:28.100]  experience so I'm a victim therefore I'm going to stay over here on the victim couch because
# [29:28.100 --> 29:33.620]  mine's not actually self-hate see that's not my fault that this happened to me so I'm just going
# [29:33.620 --> 29:38.420]  to stay here because self-hate it's just like whatever because I don't belong in your group so
# [29:38.420 --> 29:43.860]  I'll just stay on the couch and safe in here but I choose to go okay self-hate wow so now I'm actually
# [29:43.860 --> 29:48.420]  intrigued by it so when I feel a feeling of self-hate in my body I'm like really we're going to go
# [29:48.420 --> 29:59.300]  with that and then my self-hate goes meh and I go ha ha ha hmm you know and why would I hate on myself
# [29:59.300 --> 30:03.540]  okay to stand in front of thousands of people do you know what that takes you know it turned me
# [30:03.540 --> 30:08.020]  inside out for days and days and days and days and weeks but I did it anyway because I wanted to and
# [30:08.020 --> 30:13.540]  one of the most incredible experiences about being on creative live about being a speaker is that
# [30:15.300 --> 30:21.300]  every single time that voice comes up in my head and says you know you're not good enough to
# [30:21.300 --> 30:28.900]  stand up there I go for some people I may not be but for a whole bunch of people I will be
# [30:30.020 --> 30:34.660]  and that's why I'm here for the ones that want me to stand up there and whether that's four
# [30:34.660 --> 30:40.660]  people that are watching at home you know or a hundred thousand that message me that's my
# [30:40.660 --> 30:45.700]  decision and the voice of self-hate will rear up and it will mirror back to me over and over again
# [30:45.700 --> 30:51.860]  and I choose now not to be affected by it and I choose not to listen to it okay I'm 41 years old
# [30:51.860 --> 31:01.140]  I'm single and I'm a little bit fat that's life I've had a good one it's all paid for I'm honest
# [31:01.780 --> 31:09.060]  I love my job I'm wealth building I try every day to grow both in my personal self spiritually
# [31:09.060 --> 31:16.500]  financially I'm addicted to learning about my mind and business and human nature I love to share and
# [31:16.500 --> 31:22.500]  teach and photograph people I will photograph people till the day I die what a gift I have
# [31:22.500 --> 31:28.580]  been given what a gift I have been given but I choose from this day forth to be good enough
# [31:28.580 --> 31:36.340]  now I don't need to be younger I don't need to be slimmer I'm good enough now I'm smart enough
# [31:36.340 --> 31:43.460]  now my body is perfect now it is healthy I don't care what you think of it it is the greatest
# [31:43.460 --> 31:52.660]  instrument you will ever own stretch right so for the first time in my life I have discovered the
# [31:52.660 --> 31:58.740]  voice of self-hate and when I discovered it and I and I conquered it I realized I no longer have
# [31:58.740 --> 32:04.580]  any fear so now doesn't mean it doesn't come back I just address it every single day and have since
# [32:04.580 --> 32:11.220]  Christmas so it's been me and me and self-hate have been together since you know teenage years
# [32:11.220 --> 32:15.300]  and we're dealing with it now since my and it's an interesting relationship you know but it has no
# [32:15.300 --> 32:20.020]  control over me now and when it does come up I address it immediately in fact I'm quite intrigued
# [32:20.020 --> 32:26.100]  by it and I'm like wow you're the voice that told me I wasn't good enough and this whole time
# [32:26.100 --> 32:35.620]  I could have just told you to shut up so then the next block would be small thinking small thinking
# [32:35.620 --> 32:41.620]  small thinking small thinking none of us think big enough none of you think big enough whatever
# [32:41.620 --> 32:45.460]  number you put on what you want to earn in a week what was your average sale with how many shoots
# [32:46.100 --> 32:53.700]  quadruple it think about it you came in too small and you're worth more in fact I think you wrote
# [32:53.700 --> 32:59.060]  down exactly what you think you deserve no I think you doubled what you think you deserved
# [32:59.060 --> 33:03.220]  because you thought that was a big number you probably quadrupled it too and then you wrote a
# [33:03.220 --> 33:09.380]  nice safe number of money that wouldn't offend anybody in your family if you got wealthier than
# [33:09.380 --> 33:18.980]  them interesting you know and that their small thinking will cripple you also so if yours is not
# [33:18.980 --> 33:24.100]  if yours is not much self-hate and it's a whole lot of small thinking open up you don't need to
# [33:24.100 --> 33:30.020]  think big you just need to think open wide okay I am open to earning money in my business don't
# [33:30.020 --> 33:37.060]  put a number on it I want to work three days a week and create an abundant income then lift your
# [33:37.060 --> 33:43.380]  average think about it the negative voice the negative voice in your head is purely self-hate
# [33:44.340 --> 33:50.100]  that's it it's a pattern you learned when you were young children learn it we're teaching it to our
# [33:50.100 --> 33:55.220]  children yes they'll be in therapy you know blaming you it's okay we blamed our parents
# [33:55.940 --> 33:59.860]  and then they'll learn like everybody else to love themselves the way they need to be loved
# [33:59.860 --> 34:04.820]  because everybody needs to be loved differently and sometimes we don't get enough and we cry about it
# [34:05.460 --> 34:13.060]  for like an eternity like our whole life and that book liberated me there is nothing wrong with you
# [34:13.060 --> 34:19.460]  by cherry hubba it liberated me and it did it in the most powerful way and I can't believe she
# [34:19.460 --> 34:30.180]  made it that basic the victim mentality that thread turned to victim within 20 comments
# [34:30.820 --> 34:35.380]  because the second we stopped owning our own shed we started to predict it on everybody around us
# [34:36.980 --> 34:43.940]  I just don't believe in a scarcity mentality anymore I believe in an abundant amazing
# [34:44.500 --> 34:51.140]  community around me and I believe in a community that has a balance of love and somebody actually
# [34:51.140 --> 34:55.380]  wrote me an email the other day and said I wrote on Facebook I'm going to
# [34:55.780 --> 35:01.940]  um to Whistler is anybody got any great recommendations where to stay
# [35:01.940 --> 35:07.540]  and I got private emails one of them said you're a celebrity you should not tell people where you're
# [35:07.540 --> 35:15.940]  going that's dangerous and it's a dark dangerous world and I wrote back and I was like I'm a
# [35:15.940 --> 35:24.500]  photographer like yeah I'm not a celebrity I'm a portrait photographer a b it's a beautiful world
# [35:25.940 --> 35:29.860]  and yes it can be dark and dangerous sometimes I didn't even say when I was going to Whistler
# [35:29.860 --> 35:32.980]  whoever's going up there to meet me though I might still be there and that was three weeks ago and I
# [35:32.980 --> 35:39.540]  didn't go but I choose not to see the world like that and yes it can be dark and it can be dangerous
# [35:39.540 --> 35:44.420]  and it can be all of those things but I choose not to see that I know it's both yes and it's
# [35:44.420 --> 35:53.780]  frightening sometimes sure is certainly comforting sometimes too but the best one is the last one
# [35:54.660 --> 36:00.500]  the self-hate is the single most liberating one but the best one is competition and ego you as a
# [36:00.500 --> 36:06.500]  human incarnation were brought to this earth and given an ego the ego identifies you as somebody
# [36:06.500 --> 36:12.900]  separate from me and the ego will keep you separate from me and I believe that when you stop being in
# [36:12.900 --> 36:18.260]  your ego so much just for one moment and you and you become present that you connect with everybody
# [36:18.260 --> 36:23.140]  around you in the most incredible way and the only thing that stops you from doing that is that ego
# [36:24.740 --> 36:30.660]  I always say that quote I'm not here to compete I'm here to create
# [36:31.940 --> 36:37.140]  okay I'm not here to compete for what is already created I'm a creator and when I'm in a creator
# [36:37.140 --> 36:42.340]  energy I'm not looking at what you're doing and trying to be better than you because it's not
# [36:42.340 --> 36:46.340]  the blame or the finger pointing here it's the state with which you dwell and the state with which
# [36:46.340 --> 36:53.300]  you dwell is an energy of lack scarcity blame and hate and if that's what you are projecting
# [36:53.300 --> 36:57.300]  that's what you were going to get tenfold because what you put out you get back and that is a simple
# [36:57.300 --> 37:03.220]  truth you understand that so when you get on Facebook and you criticize when you go home and
# [37:03.220 --> 37:08.420]  you backstab when you go oh my god did you see Sue Bryce what she did today what she said today
# [37:08.420 --> 37:14.820]  you're the loser not the person you're talking about you're losing and you are all guilty of
# [37:14.820 --> 37:19.700]  doing that who has somebody in their life that sucks the blood out of them everybody has a
# [37:19.700 --> 37:25.380]  blood sucking friend someone that sucks the life out of you right what if I told you that was you not me
# [37:27.700 --> 37:34.500]  what if I said you're the blood sucker don't you get it the blood sucker leaves with a big smile on
# [37:34.500 --> 37:39.940]  their face you're the one sucking the life out of everybody because you either aren't standing up for
# [37:39.940 --> 37:45.460]  yourself or you're either projecting exactly the same thing back at them and you don't even
# [37:45.460 --> 37:52.100]  acknowledge it so you blame them that's mirroring ego behavior and it is frightening because when
# [37:52.100 --> 37:57.460]  you own that you have to own everything I met somebody last year at WPPI that I didn't like
# [37:58.420 --> 38:02.180]  and I didn't I don't meet many people I don't like you know you meet people you you're like
# [38:02.180 --> 38:07.780]  meh but you don't meet many people you don't like and I did not like this person like and in fact I
# [38:07.780 --> 38:12.340]  would go so far to say and it's a very strong word that I hated this person
# [38:12.340 --> 38:17.380]  and we have a mutual friend and that mutual friend was like I can't believe you hate you hate him
# [38:17.380 --> 38:24.340]  I was like I can't I don't want that person within a 50 mile radius of me and she said why and I
# [38:24.340 --> 38:31.620]  searched for the answer within myself I searched for it what is he doing that I do and I went
# [38:31.620 --> 38:35.940]  through the list of all the judgments that I put on him and I did not acknowledge one of them as
# [38:36.660 --> 38:42.420]  I did not acknowledge one of them as being something I do so it bugged the hell out of me
# [38:42.420 --> 38:47.540]  until I talked to that mutual friend again and she said I get it I know I know he can be a bit
# [38:47.540 --> 38:52.580]  difficult he is a deeply insecure person and when my friend said that I felt like somebody
# [38:53.220 --> 38:59.780]  knifed me in the chest and I said I've got to go can I call you back and I sat down and I started
# [38:59.780 --> 39:07.220]  to cry because that word hit me so hard why I was so repelled by this person is because I was in a
# [39:07.220 --> 39:14.340]  state of deep insecurity at that moment and I was repelled by that energy so I attracted it immediately
# [39:14.340 --> 39:21.380]  saw it and then hated it and I hated it about myself so what I did was I went away and I went
# [39:21.380 --> 39:28.420]  quiet time and I thought about that insecurity not in him but in me and I addressed it and you know
# ...
# [52:05.700 --> 52:10.500]  then you are doing it so check the people around you and then acknowledge it in yourself
# [52:11.460 --> 52:18.500]  first not them you right now that I've cleared the path for now you know that path's going to
# [52:18.500 --> 52:24.180]  fill up again I'll tell you how I started to turn it around I found this cool site called wealth
# [52:24.180 --> 52:28.180]  dynamics you can choose to do it or not I don't subscribe to them or sponsored by them so I'm
# [52:28.180 --> 52:33.060]  not going to link them wealth dynamics and it might even be the theory that you subscribe to
# [52:33.060 --> 52:38.340]  because there's lots of other systems like this in the world so I'm not saying this is the best one
# [52:38.340 --> 52:43.540]  I'm just saying this one worked for me I figured that people were writing books about becoming rich
# [52:44.580 --> 52:49.380]  and if that was something you could learn then surely I should read these books because I'm poor
# [52:50.500 --> 52:58.420]  so I read these books rich dad poor dad read the books rich dad poor dad richest man in Babylon
# [52:59.380 --> 53:04.340]  and then you start the practice but that's kind of not the easy part the practice is something
# [53:04.340 --> 53:10.500]  that's quite long and it's intense and of course I read richest man in Babylon and rich
# [53:10.500 --> 53:19.620]  airport and they did liberate me from thought then I read a free pdf called the science of getting
# [53:19.620 --> 53:27.060]  rich by Wallace wattles it was written in 1910 it was actually where the base of the secret the
# [53:27.060 --> 53:33.860]  book came from he wrote that in 1910 and it challenged me on every level to create from what
# [53:33.860 --> 53:39.780]  he calls formless substance which is energy and I read that book and it changed my world
# [53:39.780 --> 53:46.260]  instantaneously because it was a language that I identified with but more importantly I realized
# [53:46.260 --> 53:52.980]  how I was pushing money away when I read that book it's easy to get it's free if you to distribute
# [53:52.980 --> 54:00.180]  around the world it just you can't change anything on it so it's I could distribute it but in fact
# [54:00.180 --> 54:05.300]  I'll ask Craig if I can download it onto the site or the blog I'll find a way and if not google it
# [54:05.300 --> 54:12.500]  the science of getting rich by Wallace wattles anyway wealth dynamics is a wealth website and
# [54:12.500 --> 54:16.740]  they've set up a structure of the sort of personality type you are if you will around your
# [54:16.740 --> 54:24.420]  career you're a creator a star a supporter a mechanic a deal maker a lord and based on what
# [54:24.500 --> 54:31.700]  you are that's your path to wealth okay so in my business I created an amazing business
# [54:32.420 --> 54:37.060]  and when I created it I didn't want to work there anymore I wanted to keep building businesses
# [54:37.860 --> 54:43.780]  but instead I stayed in the business and I started to suffer so I hired a photographer
# [54:43.780 --> 54:48.740]  thinking that that was going to free me up and it didn't and I was dying and dying and dying and
# [54:49.060 --> 54:54.340]  and then I wanted to give up photography and the idea was it wasn't about the photography
# [54:54.340 --> 54:59.860]  it was about the path that I was on once I learned that I was a creator I started to create in my
# [54:59.860 --> 55:05.700]  business I created other business plans I created marketing plans I created marketing ideas and then
# [55:05.700 --> 55:11.700]  I created training manuals and then I said and the more creating I'm doing the more powerful I am
# [55:11.700 --> 55:16.580]  the more work I'm getting the stronger I'm getting the more energy in my body because I'm thrilled
# [55:17.060 --> 55:22.180]  and the more I'm doing accounts and sales and marketing I'm filled with inertia and I don't
# [55:22.180 --> 55:26.660]  want to get up in the morning and I'm suffering and dying and then I'm creating I'm creating so
# [55:26.660 --> 55:31.220]  I realized I had to learn to create my income through that one path it's the eight paths to
# [55:31.220 --> 55:36.900]  wealth that's what he talks about and it became so clear to me I'm a creator by nature if I'm not
# [55:36.900 --> 55:42.740]  making money from creating then I can't I can't sustain an income or make an income because I
# [55:42.740 --> 55:48.020]  hate doing everything else and so that really freed me it's a hundred US dollars to do the
# [55:48.020 --> 55:53.300]  get online and do the profile so you can work out your own profile but if you study it I'm sure
# [55:53.300 --> 55:57.860]  there's lots of others that might resonate with you but that freed me understanding and really
# [55:57.860 --> 56:03.300]  the bottom line for that is that was my strength don't you get it if you follow your path of your
# [56:03.300 --> 56:08.260]  greatest strength then your greatest strength will bring you wealth because it's what you love to do
# [56:08.980 --> 56:13.860]  and that's what I've been talking to you about if you hate it it will destroy you and yet most of
# [56:13.860 --> 56:18.420]  you are doing jobs that you hate we're going to go back to the hate list so wealth dynamics was
# [56:18.420 --> 56:23.940]  not about conjuring money it wasn't about sitting on the couch wishing for the Ferrari or anything
# [56:23.940 --> 56:29.620]  of that kind what it was about was leading my true path stepping forward into my true path
# [56:29.620 --> 56:36.660]  which was being a creative photographer and I'm so sick of hearing photographers say I photograph
# [56:36.660 --> 56:42.100]  this but I want to shoot landscapes but you can't make money from that or really maybe you
# [56:42.100 --> 56:48.420]  should call Peter Lick you know like come on there's people out there anything is possible
# [56:48.420 --> 56:52.660]  you're the only one that believes it's not so if you've told yourself you can't make an income
# [56:52.660 --> 56:57.220]  doing what you love and you have to do what you hate you are slowly dying and you're rotting from
# [56:57.220 --> 57:04.260]  the inside and I can smell you from here you know and you are not nourishing your skills your
# [57:04.260 --> 57:09.300]  beliefs your path or your true power and I'm not saying give up photography and become a professional
# [57:09.300 --> 57:14.020]  creator I can stay in my photography business I just need to focus on anything in my business
# [57:14.020 --> 57:19.300]  that creates I want to create marketing plans I want to create new brands I want to create new
# [57:19.300 --> 57:24.340]  studios I want to create new spaces I want to create new images I want to create new styles I
# [57:24.340 --> 57:29.140]  want to create new you name it I want to create it and anything that takes me away from creation
# [57:29.140 --> 57:34.420]  will kill me slowly now there are people out there that are mechanics and they're engineers
# [57:34.420 --> 57:38.580]  and they're deal makers they want to make deals they want to make deals I love making deals
# [57:38.580 --> 57:42.260]  there's people out there I've got a friend in Sydney who's not a creative photographer he's
# [57:42.260 --> 57:46.580]  a family portrait photographer studio does a million dollars a year in family portraits
# [57:46.580 --> 57:52.100]  and he just loves getting the numbers for him it's all logistics it's money bums on seats he likes
# [57:52.100 --> 57:56.580]  getting the get for him he's a deal maker he's a lord that's his strength and that's why he's
# [57:56.580 --> 58:01.620]  wealthy because he follows his strength and if you don't follow your greatest power you will
# [58:01.620 --> 58:08.420]  never ever become successful that freed me immediately then I follow John Demartini because
# [58:08.420 --> 58:13.860]  I like the spiritual component of my highest values to me the highest value is exactly the
# [58:13.860 --> 58:17.940]  same thing as your strength your highest values like I said to you yesterday is the thing that
# [58:17.940 --> 58:22.980]  you do every day the thing that you do every day is your highest value because you value it enough
# [58:22.980 --> 58:27.060]  to do it every day not the thing you make yourself do every day or the thing you wish you did every
# [58:27.060 --> 58:33.460]  day so when John Demartini asked you to list your five highest values I wrote working out
# [58:34.020 --> 58:39.460]  and then I realized that I don't like working out every day I just wish I did so that's not one of
# [58:39.460 --> 58:44.260]  my highest values that's one of my highest values I wish I had so I had to cross a few things off
# [58:44.260 --> 58:49.220]  the list before I got what my five values were and the five values were the things you do every day
# [58:49.220 --> 58:56.260]  once I learned them I would only work in a space that allowed those five things to come to fruition
# [58:56.260 --> 59:01.380]  one of them for me is not educating and doing workshops because I told you why I didn't like it
# [59:01.380 --> 59:07.540]  but one of them was for me was self-mastery so this is not why I'm drawn to teach a workshop so
# [59:07.540 --> 59:11.140]  I'm drawn to teach a workshop so I can teach you what I've just told you in the last hour
# [59:11.700 --> 59:16.820]  because I have this conversation every day and sometimes I have it with complete strangers and
# [59:16.820 --> 59:23.380]  I don't know why now I do because it's one of my highest values because learning and self-mastery
# [59:23.380 --> 59:29.860]  is one of my greatest gifts and I didn't even know it until I wrote it down because he says
# [59:29.860 --> 59:34.740]  what are the conversations you have every day and I'm like oh I had this repeating conversation
# [59:34.740 --> 59:40.980]  every day for the last 20 years with every client I've ever photographed with every woman I've ever
# [59:40.980 --> 59:44.820]  met with every friend that I've ever had with every boyfriend I've ever had with my family
# [59:44.820 --> 59:49.300]  members I have this conversation with everybody I know therefore it's one of my highest values
# [59:50.660 --> 59:56.260]  wow I didn't even know that if I move towards that and work with that and stay in this space
# [59:56.260 --> 01:00:00.500]  I'm re-energized and you can always tell the difference between something you love to do and
# [01:00:00.500 --> 01:00:04.980]  something that you hate to do when you finish doing something you love you are fully energized
# [01:00:04.980 --> 01:00:09.700]  and when you finish doing something you hate it sucks the life out of you and you are lying down
# [01:00:09.700 --> 01:00:15.380]  having a nana nap or shopping eating a pound cake drinking a bottle of wine
# [01:00:17.220 --> 01:00:21.860]  so you must walk towards your right path all right and that is very very important
# [01:00:21.860 --> 01:00:28.180]  there is a clear vision and a goal setting to becoming successful and that is just basic math
# [01:00:30.100 --> 01:00:35.700]  until you tell me what you want you will not create it until you tell me what you want and value it you
# [01:00:35.700 --> 01:00:42.180]  will not bring it to fruition and until you tell me what you want and truly value it and honor that
# [01:00:42.180 --> 01:00:47.700]  you don't believe it and it will never happen so you write a list of where you want to be
# [01:00:49.140 --> 01:00:50.020]  don't write thinner
# [01:00:52.980 --> 01:01:00.020]  trust me don't lose more to life all right because you'll find yourself thinner
# [01:01:00.020 --> 01:01:04.660]  with the same problems and you'll never be thin enough
# [01:01:06.580 --> 01:01:09.780]  clear vision and goal setting is about saying where do I want to be in a year
# [01:01:11.060 --> 01:01:14.820]  I need to be financially free maybe with 20 grand in the bank I need to be fine
# [01:01:14.820 --> 01:01:18.500]  financially free where the house paid off with two million dollars in the bank what do you
# [01:01:18.500 --> 01:01:24.580]  whatever your limit is think big and just say where you want to be and set a goal and then
# [01:01:24.660 --> 01:01:29.940]  actively step towards it and believe it and hold that vision every day and work towards it
# [01:01:29.940 --> 01:01:38.900]  in an attitude of gratitude your life will significantly change magic I showed this I'm
# [01:01:38.900 --> 01:01:44.340]  sure I did on my first creative life or maybe my second I had a very bizarre experience when I
# [01:01:44.340 --> 01:01:51.220]  walked into the set of creative life in Seattle you see I drew that picture on the left two years
# [01:01:51.220 --> 01:01:58.340]  before I stepped into that set there does that freak you out do you know what's freakier about
# [01:01:58.340 --> 01:02:07.220]  that picture as I wrote underneath it a warehouse to educate photographers it was on my vision board
# [01:02:09.460 --> 01:02:12.260]  what I didn't write was and you will own it
# [01:02:21.780 --> 01:02:26.660]  so here's the thing when I when I was on the set of creative life I walked in did the tour
# [01:02:26.660 --> 01:02:30.580]  loved all the people hugged everyone fell in love with everybody there never wanted to leave didn't
# [01:02:31.300 --> 01:02:36.260]  and and then it occurred to me that everybody went out to dinner and I was too scared to eat
# [01:02:36.260 --> 01:02:40.980]  so I sat on the set and I was in the studio on my own and that is a big place to be on your own
# [01:02:40.980 --> 01:02:45.300]  and then all of a sudden it was the night before and I'm writing a keynote and I don't want to be
# [01:02:45.300 --> 01:02:50.260]  on camera in front of you people and I was trembling and I just felt this unbelievable fear
# [01:02:50.260 --> 01:02:53.860]  come into my body and I was like can I do this can I do this can I do this
# [01:02:53.860 --> 01:02:57.860]  and I just turned around frightened in this big room and I looked at that set and I went like this
# [01:02:59.140 --> 01:03:05.300]  and I looked back and I was like I've seen that before so I go through my computer and I dig out
# [01:03:05.300 --> 01:03:10.180]  this image from my vision board that I'd drawn two years before never seen creative life didn't even
# [01:03:10.180 --> 01:03:15.300]  know if they had a set then and I had drawn that picture on the left now if that is not a clear
# [01:03:15.300 --> 01:03:23.060]  vision I can't tell you what is and am I different from anybody else no all I knew is that's what I
# [01:03:23.060 --> 01:03:30.900]  wanted what I drew was what I wanted and the crazy part is is I even drew the window
# [01:03:32.740 --> 01:03:33.460]  and the floor
# [01:03:36.340 --> 01:03:42.500]  you know that is a clear vision and work towards it with gratitude and love
# [01:03:42.980 --> 01:03:48.980]  and watch it come to fruition it is very very freeing and it's a long journey ahead
# [01:03:49.620 --> 01:03:57.300]  once you have tasted flight you will forever walk the earth with your eyes turned skyward
# [01:03:57.300 --> 01:04:01.620]  for there you have been and there you will always long to return
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ffee87e7638a> in <cell line: 102>()
#     137                 video_path_local.parent / transcript_file_name,
# --> 138                 drive_whisper_path / transcript_file_name
#     139             )
#
# NameError: name 'drive_whisper_path' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ffee87e7638a> in <cell line: 102>()
#     141
#     142     except:
# --> 143         display(Markdown(f"**Transcript file created: {transcript_local_path}**"))
#
# NameError: name 'transcript_local_path' is not defined

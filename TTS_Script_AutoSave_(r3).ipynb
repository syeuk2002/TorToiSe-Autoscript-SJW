# %% [markdown]
# # Load Notebook

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# the scipy version packaged with colab is not tolerant of misformated WAV files.
# install the latest version.
# !pip3 install -U scipy

# !git clone https://github.com/jnordberg/tortoise-tts.git
# %cd tortoise-tts
# !pip3 install transformers==4.19.0
# !pip3 install -r requirements.txt
# !python3 setup.py install
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Cloning into 'tortoise-tts'...
# remote: Enumerating objects: 1481, done.
# remote: Total 1481 (delta 0), reused 0 (delta 0), pack-reused 1481
# Receiving objects: 100% (1481/1481), 53.58 MiB | 17.34 MiB/s, done.
# Resolving deltas: 100% (590/590), done.
# /content/tortoise-tts
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.2 MB 29.3 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 58.0 MB/s
# ...
#      |████████████████████████████████| 182 kB 69.9 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 41 kB 635 kB/s
# ...
#      |████████████████████████████████| 235 kB 48.0 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 40.0 MB/s
# ...
#      |████████████████████████████████| 20.2 MB 6.2 MB/s
# ...

# %%
# Imports used through the rest of the notebook.
import torch
import torchaudio
import torch.nn as nn
import torch.nn.functional as F

import IPython

from tortoise.api import TextToSpeech
from tortoise.utils.audio import load_audio, load_voice, load_voices

# This will download all the models used by Tortoise from the HuggingFace hub.
tts = TextToSpeech()
# Out:
# Downloading:   0%|          | 0.00/2.06k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.18G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/159 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/181 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# ...
# Done.
# ...
# Done.
# ...
# Done.
# ...
# Done.
# ...
# Done.
# ...
# Done.
# ...
# Done.
# ...
# Done.

# %% [markdown]
# # Train New Voice

# %%
# I recommend you upload at least 2 audio clips. They must be a WAV file, 6-10 seconds long.
CUSTOM_VOICE_NAME = "cc"

import os
from google.colab import files

custom_voice_folder = f"tortoise/voices/{CUSTOM_VOICE_NAME}"
os.makedirs(custom_voice_folder)
for i, file_data in enumerate(files.upload().values()):
  with open(os.path.join(custom_voice_folder, f'{i}.wav'), 'wb') as f:
    f.write(file_data)
# Out:
#      <input type="file" id="files-358655de-f568-4c9c-9785-f25c8227a06e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-358655de-f568-4c9c-9785-f25c8227a06e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Script

# %%
preset= "fast"

# 001
text= """
Chase!
Chase!
Chase!
Chase!
Chase!
Chase!
"""

# Pick one of the voices from the output above
voice = 'tc'

# Load it and send it through Tortoise.
voice_samples, conditioning_latents = load_voice(voice)
gen = tts.tts_with_preset(text, voice_samples=voice_samples, conditioning_latents=conditioning_latents, 
                          preset=preset)
torchaudio.save('script_001.wav', gen.squeeze(0).cpu(), 24000)
IPython.display.Audio('script_001.wav')
# Out:
# Generating autoregressive samples..
# 100%|██████████| 6/6 [00:21<00:00,  3.60s/it]
# Computing best candidates using CLVP and CVVP
#   0%|          | 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/checkpoint.py:25: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# 100%|██████████| 6/6 [00:17<00:00,  2.90s/it]
# Transforming autoregressive outputs into audio..
# 100%|██████████| 80/80 [00:08<00:00,  9.12it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 002
preset= "fast"
text= """
Gaines was barking at him again. He slowly sank under the water, listening as Coach’s voice became a muffled drone.
He was so fucked. On so many levels. Except for the one that actually sounded appealing.
"""

# Pick one of the voices from the output above
voice = 'sns'

# Load it and send it through Tortoise.
voice_samples, conditioning_latents = load_voice(voice)
gen = tts.tts_with_preset(text, voice_samples=voice_samples, conditioning_latents=conditioning_latents, 
                          preset=preset)
torchaudio.save('script_002.wav', gen.squeeze(0).cpu(), 24000)
IPython.display.Audio('script_002.wav')
# Out:
# /content/tortoise-tts/tortoise/utils/audio.py:14: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampling_rate, data = read(full_path)
# Generating autoregressive samples..
# 100%|██████████| 6/6 [01:05<00:00, 10.84s/it]
# Computing best candidates using CLVP and CVVP
# 100%|██████████| 6/6 [00:18<00:00,  3.09s/it]
# Transforming autoregressive outputs into audio..
# 100%|██████████| 80/80 [00:43<00:00,  1.84it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 003
preset= "fast"
text= """
Gaines watched as Chase remained in the water after the rest of the team had gone to the lockers. 
When the lad pulled himself slowly out of the pool. Gaines was right there. Ready.
"""

# Pick one of the voices from the output above
voice = 'sns'

# Load it and send it through Tortoise.
voice_samples, conditioning_latents = load_voice(voice)
gen = tts.tts_with_preset(text, voice_samples=voice_samples, conditioning_latents=conditioning_latents, 
                          preset=preset)
torchaudio.save('script_003.wav', gen.squeeze(0).cpu(), 24000)
IPython.display.Audio('script_003.wav')
# Out:
# Generating autoregressive samples..
# 100%|██████████| 6/6 [00:47<00:00,  7.85s/it]
# Computing best candidates using CLVP and CVVP
# 100%|██████████| 6/6 [00:18<00:00,  3.05s/it]
# Transforming autoregressive outputs into audio..
#  22%|██▎       | 18/80 [00:05<00:17,  3.51it/s]

# %%
# 004
preset= "fast"
text= """
What the hell, Crisley?
What the hell, Crisley?
What the hell, Crisley?
What the hell, Crisley?
What the hell, Crisley?
What the hell, Crisley?
"""

# Pick one of the voices from the output above
voice = 'tc'

# Load it and send it through Tortoise.
voice_samples, conditioning_latents = load_voice(voice)
gen = tts.tts_with_preset(text, voice_samples=voice_samples, conditioning_latents=conditioning_latents, 
                          preset=preset)
torchaudio.save('script_004.wav', gen.squeeze(0).cpu(), 24000)
IPython.display.Audio('script_004.wav')

# %%
# 005
preset= "fast"
text= """
What?
What?
What?
What?
What?
What?
"""

# Pick one of the voices from the output above
voice = 'cc'

# Load it and send it through Tortoise.
voice_samples, conditioning_latents = load_voice(voice)
gen = tts.tts_with_preset(text, voice_samples=voice_samples, conditioning_latents=conditioning_latents, 
                          preset=preset)
torchaudio.save('script_005.wav', gen.squeeze(0).cpu(), 24000)
IPython.display.Audio('script_005.wav')

# %%
# 006

preset= "fast"
text= """
Chase muttered.
Chase muttered.
Chase muttered.
"""

# Pick one of the voices from the output above
voice = 'sns'

# Load it and send it through Tortoise.
voice_samples, conditioning_latents = load_voice(voice)
gen = tts.tts_with_preset(text, voice_samples=voice_samples, conditioning_latents=conditioning_latents, 
                          preset=preset)
torchaudio.save('script_006.wav', gen.squeeze(0).cpu(), 24000)
IPython.display.Audio('script_006.wav')

# %%
# 007
preset= "fast"
text= """
Half an hour late.
Half an hour late.
Half an hour late.
Half an hour late.
"""

# Pick one of the voices from the output above
voice = 'tc'

# Load it and send it through Tortoise.
voice_samples, conditioning_latents = load_voice(voice)
gen = tts.tts_with_preset(text, voice_samples=voice_samples, conditioning_latents=conditioning_latents, 
                          preset=preset)
torchaudio.save('script_007.wav', gen.squeeze(0).cpu(), 24000)
IPython.display.Audio('script_007.wav')

# %%
# 008
preset= "fast"
text= """
Twenty minutes!
Twenty minutes!
Twenty minutes!
Twenty minutes!
Twenty minutes!
"""

# Pick one of the voices from the output above
voice = 'cc'

# Load it and send it through Tortoise.
voice_samples, conditioning_latents = load_voice(voice)
gen = tts.tts_with_preset(text, voice_samples=voice_samples, conditioning_latents=conditioning_latents, 
                          preset=preset)
torchaudio.save('script_008.wav', gen.squeeze(0).cpu(), 24000)
IPython.display.Audio('script_008.wav')

# %%
# 009
preset= "fast"
text= """
Don’t you dare talk back to me. A lazy performance!
Don’t you dare talk back to me. A lazy performance!
Don’t you dare talk back to me. A lazy performance!
Don’t you dare talk back to me. A lazy performance!
Don’t you dare talk back to me. A lazy performance!
"""

# Pick one of the voices from the output above
voice = 'tc'

# Load it and send it through Tortoise.
voice_samples, conditioning_latents = load_voice(voice)
gen = tts.tts_with_preset(text, voice_samples=voice_samples, conditioning_latents=conditioning_latents, 
                          preset=preset)
torchaudio.save('script_009.wav', gen.squeeze(0).cpu(), 24000)
IPython.display.Audio('script_009.wav')

# %%
# 010
preset= "fast"
text= """
It wasn’t half bad.
It wasn’t half bad.
It wasn’t that bad. If I do say so.
I wasn’t that bad.
"""

# Pick one of the voices from the output above
voice = 'cc'

# Load it and send it through Tortoise.
voice_samples, conditioning_latents = load_voice(voice)
gen = tts.tts_with_preset(text, voice_samples=voice_samples, conditioning_latents=conditioning_latents, 
                          preset=preset)
torchaudio.save('script_010.wav', gen.squeeze(0).cpu(), 24000)
IPython.display.Audio('script_010.wav')

# %% [markdown]
# # Download Files

# %%
# Save All Files
files.download('/content/tortoise-tts/script_001.wav')
files.download('/content/tortoise-tts/script_002.wav')
files.download('/content/tortoise-tts/script_003.wav')
files.download('/content/tortoise-tts/script_004.wav')
files.download('/content/tortoise-tts/script_005.wav')
files.download('/content/tortoise-tts/script_006.wav')
files.download('/content/tortoise-tts/script_007.wav')
files.download('/content/tortoise-tts/script_008.wav')
files.download('/content/tortoise-tts/script_009.wav')
files.download('/content/tortoise-tts/script_010.wav')

# %%
# Manual Preview

IPython.display.Audio('script_001.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
